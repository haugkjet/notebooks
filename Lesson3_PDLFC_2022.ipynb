# %% [markdown]
# Reminder on how to learn the lesson.
# In fastbook, "clean" is only code.
# Mer motivert dersom læring er sosialt.
# Vise prosjekter
#
# Colab, Kaggle, Own Computer, today Paperspace Gradient is used.
#
# Improve performance by moving from restnet to convnext
# How fast
# How much Memory
# How accurate
#
# GO though the dog breed classifier, more difficult than cat/dog
#
# import timm to use convnext (as string)
#
# categories are stored in the vocab object.
#
# Explanation of the picl file. Show the details of the neural network with its parameters.
#
# How to we fit a function to data.
#
# Example with simple function (3*x**2 + 2*x +1)
#
# Generate "fake data" by adding noice.
#
# Using sliders to move the parameters. Does not scale to hundreds of millions of parameters.
# Use mse as loss function
# Automate the optimalization of loss function (what happens to loss when sliders go up/down)
# Use derivative, calculate gradient (requires_grad)
# Want to answer: what happens to the loss when a/b/c is increased/decreased.
# Want the the loss to automatically go down. Gradient descent
#
# What is the mathematicel function that we are finding the paraters for, can not use quadratic since we do not know that beforehand. Need more general approach (RELU, rectified linear m*x + b)
# Many RELUS can be combined to make an arbritralrily function over 3d 4d 5d. RELUs are also computationally cheap.
# This is the basis of Deep Learning.
#
# Mistake of beginners, jump direct to advanced model. Slower itegrations
#
# Also you want to iterate on the data you have from day one. People wait too long before training any model at all. You want to find out if it is good enough (or imposiible) as early as possible.
#
# Semi supervised learning, get dramatically more out of your data,
#
# Hyper parameters (have to pick) Learning rate.  If learning rate is too big bottom will be missed. If too small, training will be slow, may stop befor bottom.
#
# Need to do many RELU, use matrix multiplication.
#
# Where is this notebook ?
#
# Example in how to make a deep learning model in excel.
# Dataset. Titanic, who survived and not
# Important to show the preparation of the data. (normalizing beetween 0 and 1)
# Fast.ai helps with this (lesson 5)
# Dependenet variable, what are we trying to predict (did they survive)?
# Data Dictionary.
# Need to convert text fields to numbers. (e.g isMale)
# Using gradient descent. Solving both using traditional regression and dep learning.
